# %%
# List of integers
numbers = [1, 2, 3, 4, 5]

# Mixed data types
mixed_list = [1, "code", 3.14, True]

# Nested lists
matrix = [[1,2], [3, 4]]
type(matrix)
# Out:
# list

# %%
numbers=[0,1,2,3,4,5]
subset=numbers[::-1]
print(subset)
# Out:
# [5, 4, 3, 2, 1, 0]

# %%
numbers=[0,1,2,3,4,5]
subset=numbers[::-1]
print(subset)
# Out:
# [5, 4, 3, 2, 1, 0]

# %%
for fruit in ["apple", "banana", "cherry"]:
    print (fruit)
    for i, fruit in enumerate(fruit):
        print(f"Index {i}:{fruit}")
# Out:
# apple
# Index 0:a
# Index 1:p
# Index 2:p
# Index 3:l
# Index 4:e
# banana
# Index 0:b
# Index 1:a
# Index 2:n
# Index 3:a
# Index 4:n
# Index 5:a
# cherry
# Index 0:c
# Index 1:h
# Index 2:e
# Index 3:r
# Index 4:r
# Index 5:y

# %%
point= (10,20)
x,y = point
print(point)
print (type(point))
# Out:
# (10, 20)
# <class 'tuple'>

# %%
point=(10,20)
dir(tuple)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'count',
#  'index']

# %%
point = (10,20)
x,y = point
print(point)
print (type(point))
print(type(x))
# Out:
# (10, 20)
# <class 'tuple'>
# <class 'int'>

# %%
print(point.index(x))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 print(point(x))
#
# NameError: name 'point' is not defined

# %%
point.index(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 point.index(x)
#
# NameError: name 'point' is not defined

# %%
print(point.index(y))
# Out:
# 1

# %%
students=[("alice",85),("Bob",90),("Charlie",78)]
students[1][0]
# Out:
# 'Bob'

# %%
squares = [x**2 for x in numbers if x%2==0]
print (squares)
# Out:
# [0, 4, 16]

# %%
numbers=[1,2,4,5,6,8,9]
squares = [x**2 for x in numbers]
print (squares)
# Out:
# [1, 4, 16, 25, 36, 64, 81]

# %%
y=[]
for x in numbers:
    z=x**2
    y.append(z)
print(y)
# Out:
# [1, 4, 16, 25, 36, 64, 81]

# %%
odd = [x for x in range(10) if x%2!=0]
print(odd)
# Out:
# [1, 3, 5, 7, 9]

# %%
s="Learning python programmming"
vowels= [char for char in s if char not in "aeiou"]
print(vowels,end ='')
# Out:
# ['L', 'r', 'n', 'n', 'g', ' ', 'p', 'y', 't', 'h', 'n', ' ', 'p', 'r', 'g', 'r', 'm', 'm', 'm', 'n', 'g']

# %%
empty_dict={}
student={
    "name":"Manish",
    "age":21,
    "courses":["Maths","Physics"]}
print(student)
# Out:
# {'name': 'Manish', 'age': 21, 'courses': ['Maths', 'Physics']}

# %%
student["address"]="Kathmandu, Nepal"
print(student)
# Out:
# {'name': 'Manish', 'age': 21, 'courses': ['Maths', 'Physics'], 'address': 'Kathmandu, Nepal'}

# %%
print(student.get("age"))
print(student.get("name"))
print(student.get("courses")[0])
# Out:
# 21
# Manish
# Maths

# %%
grades = dict([("Math",90),("Physics",85)])
print(grades)
# Out:
# {'Math': 90, 'Physics': 85}

# %%
employee = dict(
    name="Bob",
    department="HR",
    employee_id=9876,
    years_of_service=5
)
print(employee)
print(grades)
print(type(employee))
type(employee)
# Out:
# {'name': 'Bob', 'department': 'HR', 'employee_id': 9876, 'years_of_service': 5}
# {'Math': 90, 'Physics': 85}
# <class 'dict'>
# dict

# %%
dir(dict)
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
employee.clear()
print(employee)
# Out:
# {}

# %%
employee.values()
# Out:
# dict_values([])

# %%
employee.keys()
# Out:
# dict_keys([])

# %%
employee = dict(
    name="Bob",
    department="HR",
    employee_id=9876,
    years_of_service=5
)
employee.values()
# Out:
# dict_values(['Bob', 'HR', 9876, 5])

# %%
employee.keys()
# Out:
# dict_keys(['name', 'department', 'employee_id', 'years_of_service'])

# %%
for i in employee.values():
    print(i)
# Out:
# Bob
# HR
# 9876
# 5

# %%
for i in employee.items():
    print(i)
# Out:
# ('name', 'Bob')
# ('department', 'HR')
# ('employee_id', 9876)
# ('years_of_service', 5)

# %%
for i in employee:
    print(i)
# Out:
# name
# department
# employee_id
# years_of_service

# %%
for i in employee.keys():
    print(i)
# Out:
# name
# department
# employee_id
# years_of_service

# %%
employee = dict(
    name="Bob",
    department="HR",
    employee_id=9876,
    years_of_service=5
)
print(employee)
print(type(employee))
type(employee)
# Out:
# {'name': 'Bob', 'department': 'HR', 'employee_id': 9876, 'years_of_service': 5}
# <class 'dict'>
# dict
