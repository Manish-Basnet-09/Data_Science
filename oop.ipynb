# %%
"""#### Session Objectives:
*   Understand the motivation behind Object-Oriented Programming.
*   Learn the core concepts: Classes, Objects, Attributes, and Methods.
*   Learn how to define a simple class in Python.
*   Understand the purpose and usage of the `__init__` constructor method.
*   Learn how to create instances (objects) of a class.
*   Learn how to access object attributes and call object methods.

    OOPs:
Analogy: Building a house
    A class is like a blueprint — it defines the structure and features (walls, doors, rooms).
    An object is a real house built from that blueprint — each with its own color, size, and number of rooms.

OOP helps by:
    Organizing code around real-world concepts
    Making it easier to reuse, extend, and maintain
    Allowing creation of multiple unique instances from a single design"""

# %%
class Dog:
    pass
#creating dog objects
dog1 = Dog()
dog2 = Dog()

print(type(dog1))
print(type(dog2))

print(dog1)
print(dog2)
print(dog1 == dog2)
# Out:
# <class '__main__.Dog'>
# <class '__main__.Dog'>
# ...
# False

# %%
class Dog:

    def __init__(self, name, breed, age):
        self.name = name
        self.breed =breed
        self.age = age
        print(f"A new Dog object named {self.name} was created!")

#creating dog objects with attributes
dog1 = Dog("Buddy", "Golden Retriever", 3)
dog2 = Dog("Lucy", "German Shepherd", 5)
dog1.nam
# Out:
# A new Dog object named Buddy was created!
# A new Dog object named Lucy was created!
# 'Buddy'

# %%
# Accessing Attributes
# We use the dot (`.`)

# `object_name.attribute_name`


print(f"Dog 1's Name: {dog1.name}")
print(f"Dog 1's Breed: {dog1.breed}")
print(f"Dog 1's Age: {dog1.age}")


print(f"\nDog 2's Name: {dog2.name}")
print(f"Dog 2's Breed: {dog2.breed}")
print(f"Dog 2's Age: {dog2.age}")

print(f"\nIs dog1's name the same as dog2's name? {dog1.name == dog2.name}")
# Out:
# Dog 1's Name: Buddy
# Dog 1's Breed: Golden Retriever
# Dog 1's Age: 3
#
# Dog 2's Name: Lucy
# Dog 2's Breed: German Shepherd
# Dog 2's Age: 5
#
# Is dog1's name the same as dog2's name? False

# %%
### Defining Methods

# Methods are functions defined inside a class that define the object's behavior. They also take `self` as the first parameter,
# allowing them to access and modify the object's attributes.


class Dog:
    def __init__(self, name, breed, age):
        self.name = name
        self.breed = breed
        self.age = age
        print(f"A new Dog object named {self.name} was created!")


    def bark(self):
        print(f"{self.name} says: Bhau! Bhau!")

    def describe(self):
        print(f"This is {self.name}, a {self.age}-year-old {self.breed}.")

    def have_birthday(self):
        self.age += 1
        print(f"Happy Birthday, {self.name}! You are now {self.age} years old.")

dog1 = Dog("Tiger", "Bull Dog", 5)
dog2 = Dog("Ashutosh", "Bhote kukur", 21)

dog2.bark()
dog2.describe()
dog2.have_birthday()
# Out:
# A new Dog object named Tiger was created!
# A new Dog object named Ashutosh was created!
# Ashutosh says: Bhau! Bhau!
# This is Ashutosh, a 21-year-old Bhote kukur.
# Happy Birthday, Ashutosh! You are now 22 years old.

# %%
class Dog:
    def __init__(self, name, breed, age):
        self.name = name
        self.breed = breed
        self.age = age
        print(f"A new Dog object named {self.name} was created!")


    def bark(self):
        print(f"{self.name} says: Bhau! Bhau!")

    def describe(self,location):
        print(f"This is {self.name}, a {self.age}-year-old {self.breed}. Normally found in {location}")

    def have_birthday(self):
        self.age += 1
        print(f"Happy Birthday, {self.name}! You are now {self.age} years old.")

dog1 = Dog("Tiger", "Bull Dog", 5)
dog2 = Dog("Ashutosh", "Bhote kukur", 21)

dog2.describe("street")
# Out:
# A new Dog object named Tiger was created!
# A new Dog object named Ashutosh was created!
# This is Ashutosh, a 21-year-old Bhote kukur. Normally found in street

# %%
class Student:
    def __init__(self,name,age):
        self.name = name
        self.age = age
        
    def introduce(self, address, course):
        print(f"Hi, my name is {self.name} and I am {self.age} years old. I am from {address} and currently i am taking {course} course")

student1= Student("Manish", 21)
student2= Student("Ashutosh", 21)

student1.introduce("Khotang", "Data Science")
student2.introduce("Swyambhu", "Data Science")
# Out:
# Hi, my name is Manish and I am 21 years old. I am from Khotang and currently i am taking Data Science course
# Hi, my name is Ashutosh and I am 21 years old. I am from Swyambhu and currently i am taking Data Science course

# %%
#part 2: Ineheritence
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age
        print(f"Person object created: {self.name}")

    def introduce(self):
        print(f"Hi, my name is {self.name} and I am {self.age} years old.")

    def walk(self):
        print(f"{self.name} is walking.")
    
#create a person object
p1 = Person("Manish", 21)
p1.introduce()
p1.walk()
# Out:
# Person object created: Manish
# Hi, my name is Manish and I am 21 years old.
# Manish is walking.

# %%
class Student(Person):
    pass

s1 = Student("Abdul", 21)
print(f"Student's Name: {s1.name}")
s1.introduce()
s1.walk()
# Out:
# Person object created: Abdul
# Student's Name: Abdul
# Hi, my name is Abdul and I am 21 years old.
# Abdul is walking.

# %%
#part 2:method overrirding
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age
        print(f"Person object created: {self.name}")

    def introduce(self):
        print(f"Hi, my name is {self.name} and I am {self.age} years old.")

    def walk(self):
        print(f"{self.name} is walking.")
        
class Student(Person):
    
    def __init__(self,name,age,student_id,course):
        super().__init__(name,age)
        self.student_id = student_id
        self.course = course

    def introduce(self):
        super().introduce()
        print(f"Hello, I am {self.name}, My student id is {self.student_id} and I am admitted in {self.course} course")


s1 = Student("Osama Bin Laaden", 21,"ID12312", "Terrrorism" )

s1.introduce()
# Out:
# Person object created: Osama Bin Laaden
# Hi, my name is Osama Bin Laaden and I am 21 years old.
# Hello, I am Osama Bin Laaden, My student id is ID12312 and I am admitted in Terrrorism course

# %%
#Encapsultaion

class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age
        #print(f"Person object created: {self.name}")

    def introduce(self):
        print(f"Hi, my name is {self.name} and I am {self.age} years old.")

    def walk(self):
        print(f"{self.name} is walking.")
        
class Student(Person):
    
    def __init__(self,name,age,student_id,course):
        super().__init__(name,age)
        self.student_id = student_id
        self.course = course

    def introduce(self):
        super().introduce()
        print(f"Hello, I am {self.name}, My student id is {self.student_id} and I am admitted in {self.course} course")


s1 = Student("Osama Bin Laaden", 21,"ID12312", "Terrrorism" )

s1.name="Abdul Sheikh Hussain"
s1.name
# Out:
# Person object created: Osama Bin Laaden
# 'Abdul Sheikh Hussain'

# %%
# ## Part 3: Encapsulation

# It involves **restricting direct access** to some of an object's components (data hiding).

# **Why use Encapsulation?**
# *   **Data Protection:** Prevent accidental or unwanted modification of an object's internal state from outside the class.
# *   **Control:** The class controls how its data is accessed and modified (e.g., through specific methods like `deposit()` or `withdraw()` instead of directly changing a `balance` attribute).
# *   **Simplicity:** Hides complex internal details from the user of the class, providing a simpler interface.
# *   **Flexibility:** The internal implementation can change without affecting the code that uses the class, as long as the public interface (methods) remains the same.

# %%
class BankAccount:
    def __init__(self, owner, initial_balance=0):
        self.owner = owner
        self._balance = initial_balance
        self.__pin = "5678"
        print(f"Account created for {self.owner}")

    def intro(self):
        print(f"Owner Name:{self.owner}")
       
    # Public method to deposit money
    def deposit(self, amount):
        if amount > 0:
            self._balance += amount
            print(f"Deposited ${amount}. New balance: ${self._balance}")
        else:
            print("Deposit amount must be positive.")

    # Public method to withdraw money
    def withdraw(self, amount):
        if amount <= 0:
            print("Withdrawal amount must be positive.")
        elif amount > self._balance:
            print(f"Insufficient funds. Cannot withdraw ${amount}. Balance is ${self._balance}")
        else:
            self._balance -= amount
            print(f"Withdrew ${amount}. New balance: ${self._balance}")

    # Public method to get balance (controlled access)
    def get_balance(self):
        print(f"Current balance for {self.owner}: ${self._balance}")
        # We can access the "private" attribute internally
        # print(f"   (Pin : {self.__pin})")
        return self._balance

    def get_pin(self):
        if self._BankAccount__pin == self.__pin:
            print(id(self._BankAccount__pin))
            print(id(self.__pin))
           
            print(f"   (Current pin  is: {self._BankAccount__pin})")
        return self.__pin

c1 = BankAccount("Manish", 55000)
c1.get_balance()
c1.owner
# Out:
# Account created for Manish
# Current balance for Manish: $55000
# 'Manish'

# %%
c1._balance
# Out:
# 55000

# %%
c1.__pin = 1234

# %%
c1.__pin
# Out:
# 1234

# %%
c1.get_pin()
# Out:
# 3066987651696
# 3066987651696
#    (Current pin  is: 5678)
# '5678'

# %%
c1._balance = 50000000000000
c1._balance
c1.get_balance()
# Out:
# Current balance for Manish: $50000000000000
# 50000000000000

# %%
#Mangled function
c1._BankAccount__pin = 4567
c1.get_pin()
# Out:
# 3066987561424
# 3066987561424
#    (Current pin  is: 4567)
# 4567

# %%
class BankAccount:
    def __init__(self, owner, initial_balance=0):
        self.owner = owner
        self._balance = initial_balance
        self.__pin = "5678"
        print(f"Account created for {self.owner}")

    def intro(self):
        print(f"Owner Name:{self.owner}")
       
    # Public method to deposit money
    def deposit(self, amount):
        if amount > 0:
            self._balance += amount
            print(f"Deposited ${amount}. New balance: ${self._balance}")
        else:
            print("Deposit amount must be positive.")

    # Public method to withdraw money
    def withdraw(self, amount):
        if amount <= 0:
            print("Withdrawal amount must be positive.")
        elif amount > self._balance:
            print(f"Insufficient funds. Cannot withdraw ${amount}. Balance is ${self._balance}")
        else:
            self._balance -= amount
            print(f"Withdrew ${amount}. New balance: ${self._balance}")

    # Public method to get balance (controlled access)
    def get_balance(self):
        print(f"Current balance for {self.owner}: ${self._balance}")
        # We can access the "private" attribute internally
        # print(f"   (Pin : {self.__pin})")
        return self._balance

    def get_pin(self):
        if self._BankAccount__pin == self.__pin:
            print(id(self._BankAccount__pin))
            print(id(self.__pin))
           
            print(f"   (Current pin  is: {self._BankAccount__pin})")
        return self.__pin

    def change_pin(self, new_pin):
        self.__pin = new_pin
        print(f"Pin changed successfully!")

        
c1 = BankAccount("Manish", 55000)
c1.change_pin(3456)
c1.get_pin()
# Out:
# Account created for Manish
# Pin changed successfully!
# 3066987563888
# 3066987563888
#    (Current pin  is: 3456)
# 3456

# %% [markdown]
# # abstraction

# %%
# ABC (Abstract Base Class)
from abc import ABC, abstractmethod

# Create an abstract class
class Animal(ABC):
   
    @abstractmethod
    def make_sound(self):
        pass
   
    @abstractmethod
    def move(self):
        pass
   
    def sleep(self):
        print("Zzz... sleeping")
        return

# Create concrete classes that inherit from Animal
class Dog(Animal):
   
    def make_sound(self):
        print("Bhau! Bhau!")
   
    def move(self):
        print("Running on four legs")

    def number_of_legs(self):
        print("Have four legs")

class Bird(Animal):
   
    def make_sound(self):
        print("Chirp! Chirp!")
   
    def move(self):
        print("Flying in the sky")

    def number_of_legs(self):
        print("Have 2 legs")

d1 = Dog()
b1 = Bird()
d1.make_sound()
# Out:
# Woof! Woof!

# %%
b1.move()
# Out:
# Flying in the sky

# %%
try:
    a1 = Animal()
except TypeError as e :
    print(f"Error: {e}")
finally:
    print(f"Program continues after handling the exception")
# Out:
# Error: Can't instantiate abstract class Animal with abstract methods make_sound, move
# Program continues after handling the exception

# %%
b1.sleep()
# Out:
# Zzz... sleeping

# %%
d1.sleep()
# Out:
# Zzz... sleeping

# %%
"""1: Class


Task 1:

Create a class called Book
with the following attributes: title, author,
price. Write a method display_info() that prints all the details of the book. Create two objects
of the class and display their information.


Task 2:

Write a class Circle
that has an attribute radius.
Include methods to calculate the area and circumference of the
circle. Create a circle object and print its area and circumference.


Task 3:

Design a class Student with attributes name, roll_number, and marks
(list of 5 subject marks). Write a method to calculate the average marks
and grade of the student (grade based on average: A ≥ 90, B ≥ 75, C ≥ 50, F
< 50). Test your class with one student object.



Topic
2: Inheritance


Task 1:

Create a base class Vehicle with attributes make and model
and a method display_info(). Inherit from this class to create a Car class with an additional attribute num_doors. Demonstrate creating a Car object and calling display_info().


Task 2:

Write a class Employee with attributes name and salary.
Create a subclass Manager that adds an attribute department. Include a method in Manager to display all details.


Task 3:

Design a base class Shape
with a method area()
that prints "Area not defined". Create subclasses Rectangle and Triangle that override the area() method to calculate the area correctly. Test both
subclasses.



Topic
3: Abstraction


Task 1:

Write an abstract class Vehicle with abstract methods start_engine() and stop_engine(). Implement subclasses Car and Motorcycle with their specific implementations of these methods.


Task 2:

Design an abstract class Payment with an abstract method pay(amount). Create subclasses CreditCardPayment and PayPalPayment and implement the pay() method for each. Demonstrate paying 100 units using both
methods.



Topic
4: Encapsulation


Task 1:

Write a class Employee with private attributes __name and __salary. Use getter and setter methods to access and update these
attributes. Show how changing the salary works with proper encapsulation.


Task 2:

Design a class Student with private attributes __name and __marks. Include methods to safely set marks (between 0–100) and
get the average marks. Demonstrate the functionality."""

# %%
class Employee:
     def __init__(self,__name,__salary):
        self.__name = __name
        self.__salary = __salary
        
        print(f"Employee account created for {self.__name}")
         
     def getname(self):
         print(f"The name of the employee is {self.__name}")

     def getsalary(self):
         print(f"The salary of {self.__name} : {self.__salary}")

     def changename(self,name):
        self.__name= name
        print(f"Name changed successfully!")
        
     def updatesalary(self,new_salary):
        self.__salary= new_salary
        print(f"Salary updated successfully!")
        
e1 = Employee("Manish",2000000)
e1.getname()
# Out:
# Employee account created for Manish
# The name of the employee is Manish

# %%
e1.changename("Ashutosh")
e1.getname()
# Out:
# Name changed successfully!
# The name of the employee is Ashutosh

# %%
e1.getsalary()
# Out:
# The salary of Ashutosh : 2000000

# %%
e1.updatesalary(5000000000)
e1.getsalary()
# Out:
# Salary updated successfully!
# The salary of Ashutosh : 5000000000

# %%
#POLYMORPHISM
# Polymorphism in Python

"""Polymorphism allows objects of different classes to be treated as objects of a common superclass. 
It enables functions to use entities of different types at different times.

## Key Points:
- Same interface, different behavior
- Useful in method overriding and operator overloading
- Promotes code reusability and flexibility"""
# Out:
# 'Polymorphism allows objects of different classes to be treated as objects of a common superclass. \nIt enables functions to use entities of different types at different times.\n\n## Key Points:\n- Same interface, different behavior\n- Useful in method overriding and operator overloading\n- Promotes code reusability and flexibility'

# %%
class Dog:
    def speak(self):
        print("Woof!")

class Cat:
    def __str__(self):
        return f"Cat str"
    def speak(self):
        print("Meow!")

class Duck:
    def speak(self):
        print("Quack!")

   

dog = Dog()
cat = Cat()
duck = Duck()
animal=[dog, cat, duck]

# %%
def make_speak(animals):
    animals.speak()
    
for a in animal:
    make_speak(a)
               
make_speak(cat)
# Out:
# Woof!
# Meow!
# Quack!
# Meow!

# %%
make_speak(cat)
# Out:
# Meow!

# %%
print(cat)
# Out:
# Cat str

# %%
str(cat)
# Out:
# 'Cat str'

# %%
# ### Common Magic Method: `__str__(self)`
#
# *   **Purpose:** Returns a user-friendly string representation of the object.
# *   **Called By:** `print(obj)`, `str(obj)`, string formatting (like f-strings `{obj}`).
# *   **Return Value:** Must return a string.
#
# If you don't define `__str__`, Python uses a default representation (often showing the class name and memory address),
# which isn't very informativ

# %%
class Book:
    def __init__(self, title, author, pages):
        self.title = title
        self.author = author
        self.pages = pages

    def __str__(self):
        return f"Title: {self.title}, Book Author :{self.author}"
       
# Create a book instance
book1 = Book("Python Crash Course", "Eric Matthes", 193)

# Print the book object
print("--- Printing book object (default) ---")
print(book1)
print(str(book1))
# Out:
# --- Printing book object (default) ---
# Title: Python Crash Course, Book Author :Eric Matthes
# Title: Python Crash Course, Book Author :Eric Matthes

# %%
class House:
    def __init__(self, owner, member, vehicle):
        self.owner = owner
        self.member = member
        self.vehicle = vehicle

    def __str__(self):
        # This defines what print(house_object) will show
        return f"Owned by '{self.owner}' with {self.member} members and have ({self.vehicle}) vehicles."

# Create a house instance
house1 = House("Manish Basnet", 4, 193)

# Print the house object
print("--- Printing house object (default) ---")
print(house1)
print(str(house1))
# Out:
# --- Printing house object (default) ---
# Owned by 'Manish Basnet' with 4 members and have (193) vehicles.
# Owned by 'Manish Basnet' with 4 members and have (193) vehicles.

# %%
class Point:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other):
        return self.x + other.x, self.y + other.y

    def __str__(self):
        return f"({self.x}, {self.y})"

p1 = Point(1, 2)
p2 = Point(3, 4)
p3 = p1+p2
print(p3)
# Out:
# (4, 6)

# %%
class Point:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other):
        return self.x + other.x, self.y + other.y

    def __sub__(self, other):
        return self.x - other.x, self.y - other.y

    def __mul__(self, other):
        return self.x / other.x, self.y / other.y


    def __str__(self):
        return f"({self.x}, {self.y})"

p1 = Point(1, 2)
p2 = Point(3, 4)
p3 = p1*p2
print(p3)
# Out:
# (0.3333333333333333, 0.5)

# %%
class Playlist:
    def __init__(self, name):
        self.name = name
        self._songs = []

    def add_song(self, title):
        self._songs.append(title)
        print(f"Added '{title}' to playlist '{self.name}'.")

    def __len__(self):
        return len(self._songs)

   
    def __str__(self):
        song_list = "\n  - ".join(self._songs)
        if not song_list:
             return f"Playlist '{self.name}' (0 songs)"
        return f"Playlist '{self.name}' ({len(self)} songs):\n  - {song_list}"


# Create a playlist
my_playlist = Playlist("Bhojpuri Vibes")

my_playlist.add_song("Lollipop Laagelu")
my_playlist.add_song("Rinkiya ke papa")
my_playlist.add_song("Tohori Hamri")

print(f"Length of playlist: {len(my_playlist)}")
print(my_playlist)
# Out:
# Added 'Lollipop Laagelu' to playlist 'Bhojpuri Vibes'.
# Added 'Rinkiya ke papa' to playlist 'Bhojpuri Vibes'.
# Added 'Tohori Hamri' to playlist 'Bhojpuri Vibes'.
# Length of playlist: 3
# Playlist 'Bhojpuri Vibes' (3 songs):
#   - Lollipop Laagelu
#   - Rinkiya ke papa
#   - Tohori Hamri

# %%
print(my_playlist.len())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 print(my_playlist.len())
#
# AttributeError: 'Playlist' object has no attribute 'len'
